# %%
#
import numpy as np
import pandas as pd
import pickle
from PIL import Image
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm

le = LabelEncoder
class ClassifierLinRegress():
    def __init__(self, data):
        self.groupXY = []
        self.image_array  = data 
        pkl_file = open('image_decoder.pkl', 'rb')
        self.le_category = pickle.load(pkl_file)
        pkl_file.close()
        self.image_array['cat_codes'] = self.le_category.transform(self.image_array['main_category'].astype('category'))   
        print(self.image_array['cat_codes'], self.image_array['main_category'])
       
        
    def lin_regress_setup(self):
        print(self.image_array.info())
        for i in range(len(self.image_array)):
            features = self.image_array['image_array'][i]
            labels = self.image_array['cat_codes'][i]
            grouped = (features, labels)
            create_tuple = tuple(grouped)
            print(create_tuple)
            self.groupXY.append(create_tuple)
       
       
        n = len(self.groupXY)
        image_size = 100
        array_size = int((image_size **2)*3)
        self.X = np.zeros((n, array_size))
        self.y = np.zeros(n)

        for arrays in range(n):
            features, labels = self.groupXY[arrays]
            self.X[arrays, :] = features
            self.y[arrays] = labels
        
    def run_linreg_class(self): 
        model = LogisticRegression(max_iter=100)
        X_train, X_test, y_train, y_test = train_test_split(self.X, self.y, test_size=0.3,random_state=0)
        model.fit(X_train, y_train)
        pred = model.predict(X_test)
        print ('accuracy:', accuracy_score(y_test, pred))
        print('report:', classification_report(y_test, pred))


if __name__ == "__main__":
    data = pd.read_pickle(r'clean_fb_image_masters.pkl')
    class_linreg = ClassifierLinRegress(data)
    print('Great Setup is finished \n')
    print(' Running Linear Regression... \n')
    class_linreg.lin_regress_setup()
    class_linreg.run_linreg_class()
# Out:
# 0         6
# 1         8
# 2         6
# 3         6
# 4         6
#          ..
# 11918     8
# 11919    12
# 11920    12
# 11921     3
# 11922    10
# Name: cat_codes, Length: 11923, dtype: int64 0                           Home & Garden
# 1            Office Furniture & Equipment
# 2                           Home & Garden
# 3                           Home & Garden
# 4                           Home & Garden
#                        ...
# 11918        Office Furniture & Equipment
# 11919              Video Games & Consoles
# 11920              Video Games & Consoles
# 11921                Computers & Software
# 11922    Phones, Mobile Phones & Telecoms
# Name: main_category, Length: 11923, dtype: object
# Great Setup is finished
#
#  Running Linear Regression...
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11923 entries, 0 to 11922
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   image_id       11923 non-null  object
#  1   product_id     11923 non-null  object
#  2   main_category  11923 non-null  object
#  3   image_array    11923 non-null  object
#  4   cat_codes      11923 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 558.9+ KB
# None
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0.1882353 , 0.15686275, 0.15294118, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.9490196 , 0.9490196 , 0.9490196 , ..., 0.25882354, 0.26666668,
#        0.28627452], dtype=float32), 6)
# (array([0.01176471, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.99607843, 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.02352941, 0.01568628, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0.01176471, 0.01176471, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.        , 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.30980393, 0.40392157, 0.2784314 , ..., 0.39607844, 0.41960785,
#        0.43529412], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.99215686, 0.99607843, 1.        , ..., 0.9843137 , 0.9882353 ,
#        0.99607843], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.3372549 , 0.41568628, 0.38039216, ..., 0.9411765 , 0.9411765 ,
#        0.9411765 ], dtype=float32), 11)
# (array([0.01568628, 0.01176471, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.01176471, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0.        , 0.01568628, 0.05490196, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.9882353 , 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.12941177, 0.13725491, 0.12941177, ..., 0.13333334, 0.14509805,
#        0.13725491], dtype=float32), 9)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.01568628, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.        , 0.        , 0.        , ..., 0.02352941, 0.01960784,
#        0.01568628], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.81960785, 0.8666667 , 0.89411765, ..., 0.9098039 , 0.9019608 ,
#        0.8980392 ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.01176471, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.00784314, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.01960784, 0.03529412, 0.04705882, ..., 0.03137255, 0.03529412,
#        0.05490196], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.30980393, 0.40392157, 0.2784314 , ..., 0.39607844, 0.41960785,
#        0.43529412], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.01568628, 0.04313726, 0.04313726, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.29411766, 0.28235295, 0.3019608 , ..., 0.70980394, 0.7058824 ,
#        0.7019608 ], dtype=float32), 5)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.01176471, 0.01568628, 0.04313726, ..., 0.        , 0.01960784,
#        0.00392157], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.8156863 , 0.8156863 , 0.8117647 , ..., 0.        , 0.        ,
#        0.00392157], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.99607843, 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 7)
# (array([0.02745098, 0.02352941, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.02745098, 0.03529412, 0.02352941, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.01176471, 0.01176471, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.89411765, 0.89411765, 0.89411765, ..., 0.9647059 , 0.9647059 ,
#        0.9647059 ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.02745098, 0.02352941, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.01568628, 0.01568628, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 8)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.7372549 , 0.7294118 , 0.73333335, ..., 0.54509807, 0.5137255 ,
#        0.48235294], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.01176471, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.9607843 , 0.9607843 , 0.9647059 , ..., 0.43137255, 0.4117647 ,
#        0.4       ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.01176471, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.01176471, 0.01176471, 0.01960784, ..., 0.00392157, 0.        ,
#        0.00784314], dtype=float32), 8)
# (array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([1.        , 1.        , 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 10)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.8       , 0.8117647 , 0.81960785, ..., 0.64705884, 0.65882355,
#        0.6666667 ], dtype=float32), 5)
# (array([1.        , 1.        , 1.        , ..., 0.69803923, 0.6901961 ,
#        0.6901961 ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.        , 0.00392157, 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.8039216 , 0.7882353 , 0.7411765 , ..., 0.9372549 , 0.92156863,
#        0.        ], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.02352941, 0.01568628, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 12)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0.03137255, 0.02745098, 0.02745098, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.        , 0.02352941, 0.05490196, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.9882353 , 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.10196079, 0.12156863, 0.10980392, ..., 0.59607846, 0.59607846,
#        0.6156863 ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.        , 0.        , 0.        , ..., 0.00392157, 0.00392157,
#        0.00392157], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.99607843, 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.9882353 , 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.        , 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.01568628, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0.01176471, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.05882353, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.02745098, 0.02352941, 0.02352941, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.        , 0.00784314, 0.02352941, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.01568628, 0.01568628, 0.01960784, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.01176471, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.78039217, 0.7607843 , 0.7529412 , ..., 0.84705883, 0.8862745 ,
#        0.8039216 ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.84313726, 0.8039216 , 0.89411765, ..., 0.8039216 , 0.8039216 ,
#        0.8039216 ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.654902  , 0.62352943, 0.58431375, ..., 0.34117648, 0.40392157,
#        0.4745098 ], dtype=float32), 4)
# (array([0.9882353 , 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 7)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.00392157, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.02352941, 0.01568628, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.9490196 , 0.9372549 , 0.92156863, ..., 0.16862746, 0.10980392,
#        0.16470589], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.50980395, 0.49803922, 0.47843137, ..., 0.98039216, 0.9647059 ,
#        0.00392157], dtype=float32), 10)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.        , 0.        , 0.00784314, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.95686275, 0.9607843 , 0.972549  , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.99607843, 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.99607843, 0.99607843, 1.        , ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.9137255, 0.9137255, 0.9098039, ..., 0.5058824, 0.5058824,
#        0.5058824], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.02745098, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.6862745 , 0.7529412 , 0.8       , ..., 0.96862745, 0.9254902 ,
#        0.9254902 ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.        , 0.        , 0.03137255, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([1.        , 1.        , 1.        , ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.09411765, 0.9647059 , 0.8980392 , ..., 1.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.01568628, 0.01176471, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.02352941, 0.02352941, 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.08627451, 0.09411765, 0.07450981, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.        , 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.01568628, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0.7607843 , 0.7607843 , 0.7647059 , ..., 0.76862746, 0.77254903,
# ...
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.        , 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.6627451 , 0.57254905, 0.64705884, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.8509804, 0.8509804, 0.8509804, ..., 0.8627451, 0.8627451,
#        0.8627451], dtype=float32), 8)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0.01568628, 0.01568628, 0.02352941, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.01176471, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.        , 0.01176471, ..., 0.01176471, 0.        ,
#        0.00784314], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0.99215686, 0.70980394, 0.5921569 , ..., 1.        , 0.9882353 ,
#        0.01568628], dtype=float32), 1)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.        , 0.02352941, 0.        , ..., 0.01960784, 0.04705882,
#        0.03921569], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.81960785, 0.8156863 , 0.80784315, ..., 0.7254902 , 0.7254902 ,
#        0.7254902 ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.04313726, 0.        , 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.02352941, 0.02352941, 0.02352941, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0.        , 0.01568628, 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.03921569, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 5)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 1)
# (array([0.04313726, 0.        , 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 6)
# (array([0.07843138, 0.02352941, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0.01568628, 0.01568628, 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0.01176471, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.        , 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.01176471, 0.02352941, 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0.01176471, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.        , 0.        , 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.        , 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0.01176471, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 11)
# (array([0.00392157, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 1)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 7)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 9)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0.60784316, 0.59607846, 0.5647059 , ..., 0.72156864, 0.4       ,
#        0.        ], dtype=float32), 6)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.02352941, 0.02352941, 0.02352941, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([1.        , 1.        , 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), 2)
# (array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 0)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 7)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 6)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 2)
# (array([0.02352941, 0.02352941, 0.02352941, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 3)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 4)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 8)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 5)
# (array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 2)
# (array([0.00392157, 0.00392157, 0.        , ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 6)
# (array([0.01176471, 0.01176471, 0.00392157, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 8)
# (array([0.01568628, 0.01568628, 0.01568628, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0.01176471, 0.01176471, 0.01176471, ..., 0.        , 0.        ,
#        0.        ], dtype=float32), 12)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 3)
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 10)
# /home/jazzy/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# accuracy: 0.16270617836175566
# report:               precision    recall  f1-score   support
#
#          0.0       0.12      0.09      0.10       278
#          1.0       0.07      0.06      0.06       189
#          2.0       0.18      0.16      0.17       224
#          3.0       0.25      0.24      0.24       309
#          4.0       0.13      0.12      0.12       270
#          5.0       0.12      0.12      0.12       317
#          6.0       0.20      0.27      0.23       414
#          7.0       0.18      0.20      0.19       298
#          8.0       0.19      0.17      0.18       343
#          9.0       0.13      0.14      0.13       266
#         10.0       0.16      0.14      0.15       218
#         11.0       0.12      0.14      0.13       229
#         12.0       0.16      0.15      0.15       222
#
#     accuracy                           0.16      3577
#    macro avg       0.15      0.15      0.15      3577
# weighted avg       0.16      0.16      0.16      3577
